# %%
import sys
import os

# Add project root to Python path
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.append(project_root)

from src.forecasting import ForecastingEngine

print("Project root added to path:", project_root)
print("Import successful!")
# Out:
# Project root added to path: c:\Users\sharo\projects\retail-ai-platform
# Import successful!

# %%
from src.forecasting import ForecastingEngine

engine = ForecastingEngine()
engine.load_sales()
engine.train()

forecast = engine.predict(product_id=10, weeks_ahead=12)
forecast
# Out:
# c:\Users\sharo\projects\retail-ai-platform\src\forecasting.py:115: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined[col] = combined[col].fillna(method="ffill").fillna(0)
#     week  predicted_quantity
# 12    13            2.319849
# 13    14            2.427780
# 14    15            2.945876
# 15    16            2.694256
# 16    17            2.483531
# 17    18            2.710580
# 18    19            2.658740
# 19    20            2.658740
# 20    21            2.658740
# 21    22            2.658740
# 22    23            2.658740
# 23    24            2.658740

# %%
forecast.isna().sum()
# Out:
# week                  0
# predicted_quantity    0
# dtype: int64

# %%
forecast.head(20)
# Out:
# Empty DataFrame
# Columns: [week, predicted_quantity]
# Index: []
